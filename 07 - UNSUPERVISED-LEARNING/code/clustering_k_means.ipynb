# %% [markdown]
# # k-Means Clustering - Code Notebook Solution
# **Author**: Dr. Yves Staudt
#
# CAS: Machine Learning - Unsupervised Learning

# %% [markdown]
# ## Loading Packages

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

import plotly.express as px

# %% [markdown]
# ## Loading Data

# %%
# Attention to adapt path
df = pd.read_csv('lego_dataset_encoded_prepared_selected_feature.csv')

# %% [markdown]
# ## Scaling Data

# %%
# set up the scaler
scaler = MinMaxScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(df)

# transform train and test sets
df_scaled = scaler.transform(df)

# %%
# let's transform the returned NumPy arrays to dataframes for the rest of
# the demo

df_scaled = pd.DataFrame(df_scaled, columns=df.columns)

# %% [markdown]
# ## K-Means

# %%
km = KMeans(
    n_clusters=3, init='random',
    n_init=10, max_iter=300,
    tol=1e-04, random_state=0
)
km.fit(df_scaled)
# Out:
# KMeans(init='random', n_clusters=3, n_init=10, random_state=0)

# %% [markdown]
# ## Cluster Centers

# %%
cluster_centers = pd.DataFrame(km.cluster_centers_, columns=df_scaled.columns)
cluster_centers
# Out:
#    Empfohlenes Alter in Jahren (mind.)  Empfohlenes Alter in Jahren (max.)
# 0                             0.215292                            1.000000  \
# 1                             0.347816                            0.995485
# 2                             0.321952                            0.984185
#
#    Verpackungsbreite  Verpackungstiefe  Verpackungshöhe  Paketgewicht
# 0           0.378691          0.432321         0.148085      0.049638  \
# 1           0.485872          0.545018         0.167986      0.091136
# 2           0.438383          0.453024         0.162030      0.067123
#
#    kein_nachhaltigkeitszertifikat  Produktfarbe_Rare  Ursprungsland_ Ungarn
# 0                        0.853535       8.673617e-18            1.665335e-16  \
# 1                        0.824390       8.673617e-18            8.780488e-01
# 2                        0.813142       1.848049e-02            3.885781e-16
#
#    Ursprungsland_ China   ...  LegoCategory_LEGO Architecture
# 0           1.000000e+00  ...                     8.673617e-18  \
# 1           1.665335e-16  ...                     1.951220e-02
# 2          -5.828671e-16  ...                     1.026694e-02
#
#    LegoCategory_LEGO Classic   LegoCategory_LEGO Ideas
# 0               -3.122502e-17              1.515152e-02  \
# 1                7.317073e-02              3.469447e-18
# 2                1.026694e-02              2.258727e-02
#
#    LegoCategory_LEGO Super Mario   LegoCategory_LEGO Friends
# 0                        0.035354                    0.156566  \
# 1                        0.009756                    0.209756
# 2                        0.078029                    0.014374
#
#    LegoCategory_LEGO Creator 3in1   LegoCategory_LEGO Minecraft
# 0                     5.050505e-03                      0.005051  \
# 1                     3.469447e-18                      0.009756
# 2                     4.106776e-02                      0.043121
#
#    LegoCategory_LEGO Spider  LegoCategory_LEGO Jurassic World
# 0                  0.015152                           0.055556  \
# 1                  0.009756                           0.004878
# 2                  0.010267                           0.002053
#
#    LegoCategory_LEGO Dots
# 0                 0.010101
# 1                 0.068293
# 2                 0.030801
#
# [3 rows x 39 columns]

# %% [markdown]
# ## Interpreting Results

# %%
df_pred = df
df_pred['cluster_predict'] = km.predict(df_scaled)

# %%
df_pred[['cluster_predict']].groupby('cluster_predict').value_counts()
# Out:
# cluster_predict
# 0    198
# 1    205
# 2    487
# Name: count, dtype: int64

# %%
df_pred.groupby('cluster_predict').describe()
# Out:
#                 Empfohlenes Alter in Jahren (mind.)
#                                               count      mean       std  min
# cluster_predict
# 0                                             198.0  6.128788  3.208860  1.5  \
# 1                                             205.0  8.978049  5.484895  1.5
# 2                                             487.0  8.421971  3.954743  1.5
#
#                                       Empfohlenes Alter in Jahren (max.)
#                  25%  50%   75%   max                              count
# cluster_predict
# 0                4.0  6.0   7.0  18.0                              198.0  \
# 1                6.0  7.0  12.0  18.0                              205.0
# 2                7.0  7.0   8.0  23.0                              487.0
#
#                             ... LegoCategory_LEGO Jurassic World
#                       mean  ...                               75%  max
# cluster_predict             ...
# 0                99.000000  ...                               0.0  1.0  \
# 1                98.575610  ...                               0.0  1.0
# 2                97.513347  ...                               0.0  1.0
#
#                 LegoCategory_LEGO Dots
#                                   count      mean       std  min  25%  50%
# cluster_predict
# 0                                 198.0  0.010101  0.100248  0.0  0.0  0.0  \
# 1                                 205.0  0.068293  0.252865  0.0  0.0  0.0
# 2                                 487.0  0.030801  0.172955  0.0  0.0  0.0
#
#
#                  75%  max
# cluster_predict
# 0                0.0  1.0
# 1                0.0  1.0
# 2                0.0  1.0
#
# [3 rows x 312 columns]

# %% [markdown]
# ## Figures

# %%
def my_boxplot_fct(data,variable):
    fig = px.box(data, x="cluster_predict", y=variable)
    fig.show()

# %%
df_pred.columns
# Out:
# Index(['Empfohlenes Alter in Jahren (mind.)',
#        'Empfohlenes Alter in Jahren (max.)', 'Verpackungsbreite',
#        'Verpackungstiefe', 'Verpackungshöhe', 'Paketgewicht',
#        'kein_nachhaltigkeitszertifikat', 'Produktfarbe_Rare',
#        'Ursprungsland_ Ungarn ', 'Ursprungsland_ China ',
#        'Ursprungsland_ Tschechische Republik ', 'Ursprungsland_Rare',
#        'Ursprungsland_ Dänemark ',
#        'EU TSD Warnung_ Keine Warnung zutreffend, Nicht für Kinder unter 36 Monaten geeignet ',
#        'EU TSD Warnung_ Nicht für Kinder unter 36 Monaten geeignet ',
#        'EU TSD Warnung_ Nicht für Kinder unter 18 Monaten geeignet ',
#        'Verpackungsart_ Box ', 'Verpackungsart_ Polybag ', 'LegoCategory_Rare',
#        'LegoCategory_LEGO Disney ', 'LegoCategory_LEGO Technic ',
#        'LegoCategory_LEGO City ', 'LegoCategory_LEGO Duplo ',
#        'LegoCategory_LEGO Star Wars ', 'LegoCategory_LEGO Ninjago ',
#        'LegoCategory_LEGO Icons ', 'LegoCategory_LEGO Marvel ',
#        'LegoCategory_LEGO Harry Potter ', 'LegoCategory_LEGO Speed Champions ',
#        'LegoCategory_LEGO Architecture ', 'LegoCategory_LEGO Classic ',
#        'LegoCategory_LEGO Ideas ', 'LegoCategory_LEGO Super Mario ',
#        'LegoCategory_LEGO Friends ', 'LegoCategory_LEGO Creator 3in1 ',
#        'LegoCategory_LEGO Minecraft ', 'LegoCategory_LEGO Spider',
#        'LegoCategory_LEGO Jurassic World ', 'LegoCategory_LEGO Dots ',
#        'cluster_predict'],
#       dtype='object')

# %%
my_boxplot_fct(df_pred, "Empfohlenes Alter in Jahren (mind.)")

# %%
my_boxplot_fct(df_pred, "Verpackungstiefe")
