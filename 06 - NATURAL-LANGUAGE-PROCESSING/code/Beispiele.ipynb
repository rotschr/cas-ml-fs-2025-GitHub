# %% [markdown]
# Word Frequencies

# %%
import math
import nltk

from textblob import TextBlob
import textblob
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wordnet2021

nltk.download('wordnet')
nltk.download('stopwords')

# Frequencies
text = TextBlob('In the beginning the Universe was created. ' +
                'This has made a lot of people very angry and been widly regarded as a bad move.')

text.word_counts('the', case_sensitive=True)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rotsc\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rotsc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File c:\Users\rotsc\anaconda3\envs\Py9\lib\site-packages\textblob\decorators.py:35, in requires_nltk_corpus.<locals>.decorated(*args, **kwargs)
#      34 try:
# ---> 35     return func(*args, **kwargs)
#      36 except LookupError as error:
#
# File c:\Users\rotsc\anaconda3\envs\Py9\lib\site-packages\textblob\tokenizers.py:60, in SentenceTokenizer.tokenize(self, text)
#      59 """Return a list of sentences."""
# ---> 60 return nltk.tokenize.sent_tokenize(text)
#
# ...
