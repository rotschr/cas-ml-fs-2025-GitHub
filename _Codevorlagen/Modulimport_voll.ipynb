# %%
import numpy as np
np.object = object   
np.bool = bool   
np.int = int  
np.float = float    
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
#from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, precision_score, recall_score, f1_score
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.utils.class_weight import compute_class_weight
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten
from tensorflow import keras
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback
#from tensorflow.keras.datasets import cifar10
from tensorflow.keras import utils, layers, models, optimizers, callbacks
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.models import Sequential, Model, load_model##
#from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots
import h5py
import scipy as sp
import imageio
from PIL import Image
import io
#from io import BytesIO
import zipfile
import textblob
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer as tf
import Levenshtein

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\rotsc\anaconda3\envs\py9\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\rotsc\anaconda3\envs\py9\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\rotsc\anaconda3\envs\py9\lib\site-packages (from nltk) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\rotsc\anaconda3\envs\py9\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\rotsc\anaconda3\envs\py9\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\rotsc\anaconda3\envs\py9\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
