# %% [markdown]
# # Create graphics
#
# Creating graphics usually takes a relatively long time. In the notebook we will discuss the most common representations and how representations can be saved. We use the `Matplotlib` library for this purpose. See [here](https://matplotlib.org/stable/tutorials/pyplot.html) for a basic introduction to Matlibplot.
#
# Since we have just discussed pandas, we assume that the data is available in pandas and is passed from there to the plots.
#
# The libraries must first be imported:

# %%
#%pip install matplotlib pandas plotly
# Out:
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: plotly in /opt/anaconda3/lib/python3.12/site-packages (5.24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import pandas as pd

# %% [markdown]
# ## Load data
#
# First we load the data we want to visualize:
#
# - On the one hand, we load the regional portraits of the Swiss municipalities from 2019 (see [here](https://opendata.swiss/de/dataset/regionalportrats-2021-kennzahlen-aller-gemeinden)). Each Swiss municipality (approx. 2000) is described with key figures on population, economy and politics.
#
# - We also land bicycle count data from the city of Zurich ([here](https://data.stadt-zuerich.ch/dataset/ted_taz_verkehrszaehlungen_werte_fussgaenger_velo)). We know the number of passing bicycles per hour at different locations in the city. We only look at the Langstrasse underpass and January 2021.

# %%
gem = pd.read_csv("gemeindeportraits.csv", sep=";", encoding="utf-8")

print(gem.info())
gem.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2172 entries, 0 to 2171
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   code                   2172 non-null   int64
#  1   gemeinde               2172 non-null   object
#  2   einwohner              2172 non-null   object
#  3   bev_dichte_km2         2172 non-null   object
#  4   auslaender_proz        2172 non-null   float64
#  5   0_19_y                 2172 non-null   float64
#  6   20_64_y                2172 non-null   float64
#  7   65_y                   2172 non-null   float64
#  8   heiratsziffer          2172 non-null   float64
#  9   scheidungsziffer       2172 non-null   float64
#  10  geburtenziffer         2172 non-null   float64
#  11  sterbeziffer           2172 non-null   float64
#  12  anz_haushalte          2172 non-null   object
#  13  haushalt_groesse       2172 non-null   float64
#  14  flaeche_km2            2172 non-null   float64
#  15  siedlung_proz          2172 non-null   float64
#  16  landw_proz             2172 non-null   float64
#  17  wald_proz              2172 non-null   float64
#  18  unprod_proz            2172 non-null   float64
#  19  beschaeftigte          2076 non-null   object
#  20  erster_sector          2136 non-null   float64
#  21  zweiter_sector         2115 non-null   object
#  22  dritter_sector         2166 non-null   object
#  23  arbeitsplaetze         1875 non-null   object
#  24  leerwohnungsziffer     2172 non-null   float64
#  25  neue_wg_pro_1000_einw  2172 non-null   float64
#  26  sozialhilfequote       1692 non-null   float64
#  27  fdp                    2127 non-null   float64
#  28  cvp                    2143 non-null   float64
#  29  sp                     2135 non-null   float64
#  30  svp                    2163 non-null   float64
#  31  evp                    1861 non-null   float64
#  32  glop                   2047 non-null   float64
#  33  bdp                    1643 non-null   float64
#  34  pda                    986 non-null    float64
#  35  gps                    2103 non-null   float64
# dtypes: float64(27), int64(1), object(8)
# memory usage: 611.0+ KB
# None
#    code            gemeinde einwohner bev_dichte_km2  auslaender_proz  0_19_y  \
# 0     1     Aeugst am Albis     1’981            250             14.2    19.8
# 1     2  Affoltern am Albis    12’303          1’162             28.7    20.2
# 2     3          Bonstetten     5’572            750             16.6    23.6
# 3     4     Hausen am Albis     3’751            276             16.0    22.2
# 4     5            Hedingen     3’778            579             16.4    21.6
#
#    20_64_y  65_y  heiratsziffer  scheidungsziffer  ...  sozialhilfequote  \
# 0     62.2  18.0            7.1               2.0  ...               1.0
# 1     61.7  18.2            5.5               1.8  ...               3.0
# 2     59.8  16.5            4.3               1.8  ...               1.5
# 3     59.8  18.0            3.2               1.6  ...               1.2
# 4     61.6  16.7            3.7               2.1  ...               1.5
#
#     fdp  cvp    sp   svp  evp  glop  bdp  pda   gps
# 0  16.4  2.5  11.6  30.4  3.2  14.3  1.3  0.2  15.1
# 1  13.4  4.5  14.6  30.3  6.6  12.7  2.0  0.2  12.6
# 2  15.4  3.9  16.7  26.1  4.2  16.2  1.3  0.2  12.4
# 3  11.1  3.9  13.7  33.2  4.1  12.4  1.6  0.2  16.7
# 4  14.0  3.9  16.7  26.6  3.7  16.4  1.9  0.2  12.3
#
# [5 rows x 36 columns]

# %%
velo = pd.read_csv("velozaehldaten_aufbereitet.csv", sep=",", encoding="utf-8")

print(velo.info())
velo.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  744 non-null    int64
#  1   ds          744 non-null    object
#  2   y           744 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 17.6+ KB
# None
#    Unnamed: 0                   ds     y
# 0           0  2021-01-01 00:00:00  22.0
# 1           1  2021-01-01 01:00:00  53.0
# 2           2  2021-01-01 02:00:00  73.0
# 3           3  2021-01-01 03:00:00  53.0
# 4           4  2021-01-01 04:00:00  36.0

# %% [markdown]
# ## Bar and pie plot
#
# What does the age structure in Zurich look like?
#
# - First we filter the data for Zurich
# - Then we select only the desired columns with the age structure
# - And finally, we make life easy for ourselves by taking the mean of this one row (makes no sense!) but get back the correct data structure for the plot

# %%
gem_zh = gem[gem["gemeinde"] == "Zürich"]
gem_zh_alt = gem_zh[["0_19_y", "20_64_y", "65_y"]].mean()
gem_zh_alt
# Out:
# 0_19_y     17.5
# 20_64_y    67.7
# 65_y       14.8
# dtype: float64

# %% [markdown]
# - We select the `bar()` plot
# - We pass the `index` of the data (i.e. the labels) as X and the percentage values of the age structure (`values`) as Y.
# - Each bar plot is assigned a fill color (`color`). All colors can be found in this [list](https://matplotlib.org/stable/gallery/color/named_colors.html#css-colors)

# %%
# Grösse des Plot
plt.figure(figsize=(8, 6))

# Typ des Plot und Inputdaten
plt.bar(gem_zh_alt.index, gem_zh_alt.values, color=['skyblue', 'salmon', 'lightgreen'])

# y-Achse soll von 0 bis 100% gehen
plt.ylim(0,100)

# Beschriftung
plt.xlabel('Altersgruppen')
plt.ylabel('Prozent der Bevölkerung')
plt.title('Altersverteilung in Zürich')

# Anzeige der Plot
plt.show()

# %% [markdown]
# - We can also display the same as a pieplot (`pie()`)
# - For pieplots, it makes sense to label the areas with the % (`autopct`)

# %%
# Grösse des Plot
plt.figure(figsize=(6, 6))

# Pie-Plot
plt.pie(gem_zh_alt.values, labels=gem_zh_alt.index, autopct='%1.1f%%', colors=['skyblue', 'salmon', 'lightgreen'])

# Beschriftung
plt.title('Altersverteilung in Zürich')
plt.show()

# %% [markdown]
# ## Scatterplot
#
# Scatterplot can be used to compare pairs of values as point distributions. How about an obligatory comparison of the foreigner rate with the social welfare rate per municipality?
#
# - We use the `scatter()` function
# - The two measurements per municipality can be passed directly as columns of the Pandas dataframe
# - Does it make sense to scale the two axes from 0-100?

# %%
# Grösse
plt.figure(figsize=(6, 4))

# Scatterplot
plt.scatter(gem["auslaender_proz"], gem["sozialhilfequote"], color='skyblue', alpha=0.6)

# Achsen Limiten
plt.xlim(0,100)
plt.ylim(0,100)

# Beschriftung
plt.xlabel('Prozent Ausländer')
plt.ylabel('Sozialhilfequote')
plt.title('Vergleich Sozialhilfequote und Anteil Ausländer')
plt.show()

# %% [markdown]
#  ## Boxplot
#
# Boxplots are very useful for comparing several numerical columns. Just as a reminder on how to read boxplots:
#
# <img src="boxplot.png" width=400/>
#
# We compare the voter shares of the largest parties across all municipalities.
#
# - We can apply the `boxplot()` directly to the (filtered) dataframe

# %%
# Grösse
plt.figure(figsize=(8, 4))

# Boxplot
gem[['svp', 'fdp', 'cvp', 'sp']].boxplot()

# Beschriftung
plt.xlabel('Parteien')
plt.ylabel('Wähleranteil')
plt.title('Wähleranteil der grössten Parteien pro Gemeinde')
plt.show()

# %% [markdown]
# ## Line and time series plot
#
# Line plots are most commonly used to visualize phenomena that have been measured multiple times. A typical example is time series, i.e. measurements of the same phenomenon that have been taken several times over time.
#
# We therefore work with bicycle count data.
#
# The simplest visualization shows all measurements in the order in which they were registered.

# %%
# Grösse
plt.figure(figsize=(14, 4))

# einfacher Lineplot
plt.plot(velo["y"], color = "darkorange")

# Beschriftung
plt.xlabel('Messung')
plt.ylabel('Anzal Velos (Stunde)')
plt.title('Messungen zur Anzahl Velos in der Langstrassenunterführung Zürich (Januar 2021)')
plt.show()

# %% [markdown]
# It gets a little more complicated if you want to display the date format appropriately.
#
# - First we have to convert the time field in the data into a datetime format (see above all the 'format' field)
# - When plotting, we transfer the time field and the measurements
# - Now comes a lot of axis formatting and labeling

# %%
velo['ds'] = pd.to_datetime(velo['ds'], format="%Y-%m-%d %H:%M:%S")

# %%
# Grösse
fig = plt.figure(figsize=(14, 4))

# Lineplot
plt.plot(velo['ds'], velo['y'], label='Velozählungen', color = "darkorange")

# Formatierung der Achsenbeschriftung
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.DayLocator())

# Welche Gridlines?
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=1))
ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m-%d'))

# Art der Gridlijnes
ax.xaxis.grid(True, which='major', linestyle='-', linewidth='0.5', color='black')
ax.xaxis.grid(True, which='minor', linestyle=':', linewidth='0.5', color='gray')

# Sonstite Beschriftung
plt.xlabel('Datum')
plt.ylabel('Anzal Velos (Stunde)')
plt.title('Messungen zur Anzahl Velos in der Langstrassenunterführung Zürich  (Januar 2021)')

plt.show()

# %% [markdown]
# ## Saving plots
#
# We like the last plot. We just save it as an image file. It is important that we have saved the plot above in the *fig* object (`fig = plt.figure(figsize=(14, 4))`).
#
# Saving as an image is now very simple:

# %%
fig.savefig("velozaehlung.png", format="png", dpi=300)

# %% [markdown]
# ## Interactive plots
#
# *Matplotlib* is good for static plots. However, if you want to explore the data interactively, you can use libraries like *Plotly*.

# %%
gem.columns
# Out:
# Index(['code', 'gemeinde', 'einwohner', 'bev_dichte_km2', 'auslaender_proz',
#        '0_19_y', '20_64_y', '65_y', 'heiratsziffer', 'scheidungsziffer',
#        'geburtenziffer', 'sterbeziffer', 'anz_haushalte', 'haushalt_groesse',
#        'flaeche_km2', 'siedlung_prou', 'landw_proz', 'wald_proz',
#        'unprod_proz', 'beschaeftigte', 'erster_sector', 'zweiter_sector',
#        'dritter_sector', 'arbeitsplaetze', 'leerwohnungsziffer',
#        'neue_wg_pro_1000_einw', 'sozialhilfequote', 'fdp', 'cvp', 'sp', 'svp',
#        'evp', 'glop', 'bdp', 'pda', 'gps'],
#       dtype='object')

# %%
import plotly.express as px

# Calculate the correlation matrix
features = [
    "sozialhilfequote",
    "auslaender_proz",
    "geburtenziffer", 
    "sterbeziffer",
    "leerwohnungsziffer", 
    "siedlung_proz",
    "landw_proz",
    "sp", 
    "svp",
    "fdp",
]
correlation_matrix = gem[features].corr()

# Create a heatmap using Plotly
fig = px.imshow(correlation_matrix, 
                text_auto=True,          # Display the correlation coefficients on the heatmap
                title='Correlation Heatmap',
                color_continuous_scale='Viridis',  # Choose a color scale
                width=800,  # Specify width
                height=800  # Specify height
                )

fig.show()
